# %%
import pandas as pd

# %%
df = pd.read_hdf("../data/car.h5")

# %%
df.shape
# Out:
# (106494, 155)

# %%
df.sample(5)
# Out:
#                                                breadcrumb  \
# 71955   [Osobowe, Toyota, Avensis, Toyota Avensis II (...
# 103675  [Osobowe, Ford, Fiesta, Ford Fiesta Mk6 (2002-...
# 140701  [Osobowe, BMW, Seria 3, 318, BMW Seria 3 F30 (...
# 54320   [Osobowe, Peugeot, 5008, Peugeot 5008 II (2017-)]
# 35422   [Osobowe, Volkswagen, Touran, Volkswagen Toura...
#
#                    created_at price_currency  \
# 71955     13:08, 3 marca 2018            PLN
# 103675  10:34, 28 lutego 2018            PLN
# 140701    10:27, 3 marca 2018            PLN
# 54320     09:58, 3 marca 2018            PLN
# 35422     17:28, 2 marca 2018            PLN
#
#                                  price_details  price_value  \
# 71955                              Cena Brutto      14900.0
# 103675                             Cena Brutto       8490.0
# 140701  Cena Netto, Do negocjacji, Faktura VAT      46260.0
# 54320                 Cena Brutto, Faktura VAT     139430.0
# ...
